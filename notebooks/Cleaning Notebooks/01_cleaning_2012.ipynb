# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Let's start by reading in one year's worth a data to get a better feel

# %%
#df = pd.read_excel('/Users/andrewroberts/desktop/ga/capstone/Data/FuelMixReport_PreviousYears/IntGenByFuel2015.xls', sheet_name = ['Dec', 'Nov', 'Oct', 'Sep', 'Aug', 'Jul', 'Jun', 'May', 'Apr', 'Mar', 'Feb', 'Jan'], index_col = 'Date-Fuel')

# %%
df = pd.read_excel('/Users/andrewroberts/desktop/ga/capstone/Data/FuelMixReport_PreviousYears/IntGenByFuel2012.xls', sheet_name = None)

# %%
df.keys()
# Out:
# dict_keys(['Dec', 'Nov', 'Oct', 'Sep', 'Aug', 'Jul', 'Jun', 'May', 'Apr', 'Mar', 'Feb', 'Jan'])

# %%
cdf = pd.concat(df,sort=False)

# %%
cdf.rename(columns = {'Date-Fuel': 'fuel'}, inplace=True)
cdf
# Out:
#                      fuel          Total     00:15:00     00:30:00  \
# Dec 0    12/01/12_Biomass     869.281425     9.694032     9.762346
#     1       12/01/12_Coal  237851.559100  2130.939640  2050.142415
#     2        12/01/12_Gas   18135.739180   156.876798   157.101716
#     3     12/01/12_Gas-CC  212497.862100  1244.165363  1213.717533
#     4      12/01/12_Hydro     707.505941     3.152086     2.785787
# ...                   ...            ...          ...          ...
# Jan 274    01/31/12-Hydro    1214.517433    12.019676    12.003854
#     275  01/31/12-Nuclear   90906.872520   948.768814   948.670106
#     276    01/31/12-Other     432.339145     3.900291     3.894856
#     277      01/31/12-Sun     128.788627     0.000000     0.000000
#     278     01/31/12-Wind   78029.002620  1535.338263  1531.580759
#
#             00:45:00     01:00:00     01:15:00     01:30:00     01:45:00  \
# Dec 0       9.803130     9.837561     9.837940     9.848034     9.858063
#     1    2001.038037  1948.494496  1902.067653  1828.057689  1762.289013
#     2     155.747037   156.319977   155.924622   156.088432   156.081391
#     3    1194.820490  1184.001406  1159.009788  1182.993112  1212.592746
#     4       2.782355     2.786000     2.763409     2.747072     2.752009
# ...              ...          ...          ...          ...          ...
# Jan 274    12.020080    12.083839    12.048898    12.076885    12.046369
#     275   948.545784   948.554942   947.487927   947.393985   947.469113
#     276     3.894896     3.891105     4.398885     4.654375     4.632175
#     277     0.000000     0.000000     0.000000     0.000000     0.000000
#     278  1529.945460  1529.057538  1528.568247  1529.304690  1524.775402
#
#             02:00:00  ...  DST4  Unnamed: 98  Unnamed: 99  Unnamed: 100  \
# Dec 0       9.886432  ...   NaN          NaN          NaN           NaN
#     1    1724.691620  ...   NaN          NaN          NaN           NaN
#     2     157.054813  ...   NaN          NaN          NaN           NaN
#     3    1234.351072  ...   NaN          NaN          NaN           NaN
#     4       2.750056  ...   NaN          NaN          NaN           NaN
# ...              ...  ...   ...          ...          ...           ...
# Jan 274    12.028494  ...   NaN          NaN          NaN           NaN
#     275   947.285932  ...   NaN          NaN          NaN           NaN
#     276     4.627292  ...   NaN          NaN          NaN           NaN
#     277     0.000000  ...   NaN          NaN          NaN           NaN
#     278  1521.435793  ...   NaN          NaN          NaN           NaN
#
#          Unnamed: 101  1900-01-01 00:00:00  dst1  dst2  dst3  dst4
# Dec 0             NaN                  NaN   NaN   NaN   NaN   NaN
#     1             NaN                  NaN   NaN   NaN   NaN   NaN
#     2             NaN                  NaN   NaN   NaN   NaN   NaN
#     3             NaN                  NaN   NaN   NaN   NaN   NaN
#     4             NaN                  NaN   NaN   NaN   NaN   NaN
# ...               ...                  ...   ...   ...   ...   ...
# Jan 274           NaN            11.480437   0.0   0.0   0.0   0.0
#     275           NaN           946.917342   0.0   0.0   0.0   0.0
#     276           NaN             4.988715   0.0   0.0   0.0   0.0
#     277           NaN             0.000000   0.0   0.0   0.0   0.0
#     278           NaN           724.857221   0.0   0.0   0.0   0.0
#
# [3300 rows x 111 columns]

# %%
date = []
fuel = []
for each in cdf['fuel']:
    date.append(each[:8])
    fuel.append(each[9:])

# %%
cdf['Date'] = date
cdf['Fuel'] = fuel

# %%
full_df = cdf[['Date', 'Fuel', 'Total']]

# %%
full_df
# Out:
#              Date     Fuel          Total
# Dec 0    12/01/12  Biomass     869.281425
#     1    12/01/12     Coal  237851.559100
#     2    12/01/12      Gas   18135.739180
#     3    12/01/12   Gas-CC  212497.862100
#     4    12/01/12    Hydro     707.505941
# ...           ...      ...            ...
# Jan 274  01/31/12    Hydro    1214.517433
#     275  01/31/12  Nuclear   90906.872520
#     276  01/31/12    Other     432.339145
#     277  01/31/12      Sun     128.788627
#     278  01/31/12     Wind   78029.002620
#
# [3300 rows x 3 columns]

# %%
full_df['Fuel'] = full_df['Fuel'].replace('Sun','Solar')
full_df['Fuel'] = full_df['Fuel'].replace('Gas_CC','Gas-CC')
# Out:
# <ipython-input-144-88ebca457217>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_df['Fuel'] = full_df['Fuel'].replace('Sun','Solar')
# <ipython-input-144-88ebca457217>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_df['Fuel'] = full_df['Fuel'].replace('Gas_CC','Gas-CC')

# %%
full_df
# Out:
#              Date     Fuel          Total
# Dec 0    12/01/12  Biomass     869.281425
#     1    12/01/12     Coal  237851.559100
#     2    12/01/12      Gas   18135.739180
#     3    12/01/12   Gas-CC  212497.862100
#     4    12/01/12    Hydro     707.505941
# ...           ...      ...            ...
# Jan 274  01/31/12    Hydro    1214.517433
#     275  01/31/12  Nuclear   90906.872520
#     276  01/31/12    Other     432.339145
#     277  01/31/12    Solar     128.788627
#     278  01/31/12     Wind   78029.002620
#
# [3300 rows x 3 columns]

# %%
# https://stackoverflow.com/questions/66792082/pandas-python-how-to-transpose-duplicate-rows-to-columns-and-preserve-order
order = full_df['Date'].unique()
full_df = full_df.set_index([full_df.groupby('Fuel').cumcount(), 'Fuel'])['Total'].unstack()

# %%
full_df
# Out:
# Fuel     Biomass         Coal          Gas       Gas-CC       Hydro  \
# 0     869.281425  237851.5591  18135.73918  212497.8621  707.505941
# 1     876.354549  257148.9385  17412.22040  204907.1217  648.231948
# 2     919.860335  273217.6515  15902.63739  258589.8982  758.143065
# 3     961.694048  261765.2689  18369.60455  276304.9815  679.989206
# 4     786.413150  246951.9593  19163.65306  306277.8899  722.931711
# ..           ...          ...          ...          ...         ...
# 367          NaN          NaN          NaN          NaN         NaN
# 368          NaN          NaN          NaN          NaN         NaN
# 369          NaN          NaN          NaN          NaN         NaN
# 370          NaN          NaN          NaN          NaN         NaN
# 371          NaN          NaN          NaN          NaN         NaN
#
# Fuel      Nuclear       Other       Solar          Wind
# 0     123916.5462  573.604937  215.930344  129841.14130
# 1     123911.9046  576.995742  197.388069  125540.31240
# 2     123870.5912  508.432071  205.926720  115198.15980
# 3     123816.6095  481.496846  139.634252   79925.34046
# 4     123963.5275  414.930121  401.044146   46272.74952
# ..            ...         ...         ...           ...
# 367           NaN         NaN  265.425939           NaN
# 368           NaN         NaN  276.557086           NaN
# 369           NaN         NaN  278.964256           NaN
# 370           NaN         NaN   72.939623           NaN
# 371           NaN         NaN  128.788627           NaN
#
# [372 rows x 9 columns]

# %%
# https://datascience.stackexchange.com/questions/48335/how-to-add-date-column-in-python-pandas-dataframe
full_df['date'] = pd.date_range(start='2012-01-01', periods=len(full_df), freq='D')

# %%
full_df
# Out:
# Fuel     Biomass         Coal          Gas       Gas-CC       Hydro  \
# 0     869.281425  237851.5591  18135.73918  212497.8621  707.505941
# 1     876.354549  257148.9385  17412.22040  204907.1217  648.231948
# 2     919.860335  273217.6515  15902.63739  258589.8982  758.143065
# 3     961.694048  261765.2689  18369.60455  276304.9815  679.989206
# 4     786.413150  246951.9593  19163.65306  306277.8899  722.931711
# ..           ...          ...          ...          ...         ...
# 367          NaN          NaN          NaN          NaN         NaN
# 368          NaN          NaN          NaN          NaN         NaN
# 369          NaN          NaN          NaN          NaN         NaN
# 370          NaN          NaN          NaN          NaN         NaN
# 371          NaN          NaN          NaN          NaN         NaN
#
# Fuel      Nuclear       Other       Solar          Wind       date
# 0     123916.5462  573.604937  215.930344  129841.14130 2012-01-01
# 1     123911.9046  576.995742  197.388069  125540.31240 2012-01-02
# 2     123870.5912  508.432071  205.926720  115198.15980 2012-01-03
# 3     123816.6095  481.496846  139.634252   79925.34046 2012-01-04
# 4     123963.5275  414.930121  401.044146   46272.74952 2012-01-05
# ..            ...         ...         ...           ...        ...
# 367           NaN         NaN  265.425939           NaN 2013-01-02
# 368           NaN         NaN  276.557086           NaN 2013-01-03
# 369           NaN         NaN  278.964256           NaN 2013-01-04
# 370           NaN         NaN   72.939623           NaN 2013-01-05
# 371           NaN         NaN  128.788627           NaN 2013-01-06
#
# [372 rows x 10 columns]

# %% [markdown]
# ### Above, we can see extra data was entered in the Solar column that proceeds into 2013. Let's remove these values.

# %%
full_df.drop(index=[366, 367, 368, 369, 370, 371], inplace=True)

# %% [markdown]
# #### Now, let's set our newly created 'date' column as our index

# %%
full_df = full_df.set_index('date')
full_df
# Out:
# Fuel            Biomass         Coal          Gas       Gas-CC        Hydro  \
# date
# 2012-01-01   869.281425  237851.5591  18135.73918  212497.8621   707.505941
# 2012-01-02   876.354549  257148.9385  17412.22040  204907.1217   648.231948
# 2012-01-03   919.860335  273217.6515  15902.63739  258589.8982   758.143065
# 2012-01-04   961.694048  261765.2689  18369.60455  276304.9815   679.989206
# 2012-01-05   786.413150  246951.9593  19163.65306  306277.8899   722.931711
# ...                 ...          ...          ...          ...          ...
# 2012-12-27  1171.592623  221504.4700  14698.39208  306072.1745  1343.688621
# 2012-12-28  1424.080312  236915.9368  19447.79707  320630.0469  1244.286600
# 2012-12-29  1406.076210  230188.3446  17708.01344  323772.8964  1212.195928
# 2012-12-30  1003.387351  220877.7854  17173.68961  291385.1311  1163.186518
# 2012-12-31   906.357552  233604.9841  16679.39593  290845.5744  1214.517433
#
# Fuel             Nuclear       Other       Solar          Wind
# date
# 2012-01-01  123916.54620  573.604937  215.930344  129841.14130
# 2012-01-02  123911.90460  576.995742  197.388069  125540.31240
# 2012-01-03  123870.59120  508.432071  205.926720  115198.15980
# 2012-01-04  123816.60950  481.496846  139.634252   79925.34046
# 2012-01-05  123963.52750  414.930121  401.044146   46272.74952
# ...                  ...         ...         ...           ...
# 2012-12-27   91008.50527  523.019886  185.725578  132041.34190
# 2012-12-28   90982.01653  505.204872   77.772401   60491.18534
# 2012-12-29   91067.89498  545.133140  185.702236   77810.74041
# 2012-12-30   90984.14252  474.941356   28.747789  139582.02680
# 2012-12-31   90906.87252  432.339145   41.921254   78029.00262
#
# [366 rows x 9 columns]

# %% [markdown]
# ### Let's combine 'Gas' & 'Gas-CC' as one column - 'NGas' for natural gas

# %%
full_df['NGas'] = full_df['Gas'] + full_df['Gas-CC']
full_df.drop(columns = ['Gas', 'Gas-CC'], inplace = True)

# %%
full_df.plot(figsize=(15,9)).legend(title='Source', bbox_to_anchor=(1, 1));

# %%
sns.pairplot(full_df, corner=True)

# %%
plt.figure(figsize=(9,9))
sns.boxplot(data = full_df,
            
            );

# %% [markdown]
# ### Export the cleaned data

# %%
full_df.to_csv('../data/final_dfs/2012_clean.csv')
