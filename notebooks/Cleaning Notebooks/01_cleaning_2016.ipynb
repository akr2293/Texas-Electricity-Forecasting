# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Let's start by reading in one year's worth a data to get a better feel

# %%
#df = pd.read_excel('/Users/andrewroberts/desktop/ga/capstone/Data/FuelMixReport_PreviousYears/IntGenByFuel2015.xls', sheet_name = ['Dec', 'Nov', 'Oct', 'Sep', 'Aug', 'Jul', 'Jun', 'May', 'Apr', 'Mar', 'Feb', 'Jan'], index_col = 'Date-Fuel')

# %%
df = pd.read_excel('/Users/andrewroberts/desktop/ga/capstone/Data/FuelMixReport_PreviousYears/IntGenByFuel2016.xlsx', sheet_name = None)

# %%
df.keys()
# Out:
# dict_keys(['Dec', 'Nov', 'Oct', 'Sep', 'Aug', 'Jul', 'Jun', 'May', 'Apr', 'Mar', 'Feb', 'Jan'])

# %%
def data_loader(file):
    full_df = []
    for key in list(df.keys()):
        if "Summary" in key:
            del df[key]
#     key = key[['Date', 'Fuel', 'Total']]
    
#     order = key['Date'].unique()
    
#     key = key.set_index([key.groupby('Fuel').cumcount(), 'Fuel'])['Total'].unstack()
    
#     df_dec['date'] = pd.date_range(start='2019-12-01', periods=len(df_dec), freq='D') 
#     df_dec = df_dec.set_index('date')
    
    
#     full_df.append(each)

# %%
# def data_loader(file):
#     full_df = []
#     for each in file:
#         if "data_Summary_1" in df:
#             del df["data_Summary_1"]
#             print('deleted')
#         if "data_Summary_2" in df:
#             del df["data_Summary_2"]
        
#         print(each)

# %%
data_loader(df)

# %%
cdf = pd.concat(df,sort=False)

# %%
cdf
# Out:
#                 Date-Fuel          Total     00:15:00     00:30:00  \
# Dec 0    12/01/16_Biomass    1368.853334    14.451498    14.468989
#     1       12/01/16_Coal  291089.503855  2734.634227  2644.593718
#     2        12/01/16_Gas   34755.195274   324.756885   329.371075
#     3     12/01/16_Gas-CC  229820.111721  1463.708736  1432.950325
#     4      12/01/16_Hydro    1344.980060     4.545706     4.836596
# ...                   ...            ...          ...          ...
# Jan 274    01/31/16_Hydro    2590.696536    25.754483    25.834411
#     275  01/31/16_Nuclear  122796.897712  1278.421693  1278.665276
#     276    01/31/16_Other      83.697152     0.903836     0.973683
#     277    01/31/16_Solar    1859.815680     0.000000     0.000000
#     278     01/31/16_Wind  143642.521471  2763.111462  2700.706913
#
#             00:45:00     01:00:00     01:15:00     01:30:00     01:45:00  \
# Dec 0      14.419026    14.410285    14.415445    14.402059    14.471164
#     1    2620.942898  2547.892906  2510.974877  2409.068646  2362.575982
#     2     328.239082   329.525942   326.443420   328.039359   328.897828
#     3    1394.307445  1359.394285  1338.222481  1317.776657  1317.392930
#     4       4.831938     4.837502     5.032782     5.128692     5.106904
# ...              ...          ...          ...          ...          ...
# Jan 274    25.819029    25.834907    24.881533    24.829242    24.840900
#     275  1279.586746  1279.493141  1279.199721  1279.162492  1279.065676
#     276     0.915057     0.833606     0.827513     0.835027     0.835260
#     277     0.000000     0.000000     0.000000     0.000000     0.000000
#     278  2641.631414  2574.079821  2546.570278  2539.282126  2523.485197
#
#             02:00:00  ...     00:00:00  DST1  DST2  DST3  DST4  \
# Dec 0      14.481883  ...    13.649795   NaN   NaN   NaN   NaN
#     1    2313.369622  ...  2944.656656   NaN   NaN   NaN   NaN
#     2     330.223434  ...   301.016456   NaN   NaN   NaN   NaN
#     3    1322.662408  ...  1551.615331   NaN   NaN   NaN   NaN
#     4       4.801135  ...     3.023621   NaN   NaN   NaN   NaN
# ...              ...  ...          ...   ...   ...   ...   ...
# Jan 274    24.848151  ...    25.179821   NaN   NaN   NaN   NaN
#     275  1279.160598  ...  1279.011133   NaN   NaN   NaN   NaN
#     276     0.831634  ...     0.988328   NaN   NaN   NaN   NaN
#     277     0.000000  ...     0.000000   NaN   NaN   NaN   NaN
#     278  2485.511096  ...  1614.411489   NaN   NaN   NaN   NaN
#
#          1900-01-01 00:00:00  dst1  dst2  dst3  dst4
# Dec 0                    NaN   NaN   NaN   NaN   NaN
#     1                    NaN   NaN   NaN   NaN   NaN
#     2                    NaN   NaN   NaN   NaN   NaN
#     3                    NaN   NaN   NaN   NaN   NaN
#     4                    NaN   NaN   NaN   NaN   NaN
# ...                      ...   ...   ...   ...   ...
# Jan 274                  NaN   NaN   NaN   NaN   NaN
#     275                  NaN   NaN   NaN   NaN   NaN
#     276                  NaN   NaN   NaN   NaN   NaN
#     277                  NaN   NaN   NaN   NaN   NaN
#     278                  NaN   NaN   NaN   NaN   NaN
#
# [3294 rows x 107 columns]

# %%
cdf.rename(columns = {'Date-Fuel': 'fuel'}, inplace=True)

cdf[['Date', 'Fuel']] = cdf.fuel.str.split("_", expand=True)

# %%
cdf
# Out:
#                      fuel          Total     00:15:00     00:30:00  \
# Dec 0    12/01/16_Biomass    1368.853334    14.451498    14.468989
#     1       12/01/16_Coal  291089.503855  2734.634227  2644.593718
#     2        12/01/16_Gas   34755.195274   324.756885   329.371075
#     3     12/01/16_Gas-CC  229820.111721  1463.708736  1432.950325
#     4      12/01/16_Hydro    1344.980060     4.545706     4.836596
# ...                   ...            ...          ...          ...
# Jan 274    01/31/16_Hydro    2590.696536    25.754483    25.834411
#     275  01/31/16_Nuclear  122796.897712  1278.421693  1278.665276
#     276    01/31/16_Other      83.697152     0.903836     0.973683
#     277    01/31/16_Solar    1859.815680     0.000000     0.000000
#     278     01/31/16_Wind  143642.521471  2763.111462  2700.706913
#
#             00:45:00     01:00:00     01:15:00     01:30:00     01:45:00  \
# Dec 0      14.419026    14.410285    14.415445    14.402059    14.471164
#     1    2620.942898  2547.892906  2510.974877  2409.068646  2362.575982
#     2     328.239082   329.525942   326.443420   328.039359   328.897828
#     3    1394.307445  1359.394285  1338.222481  1317.776657  1317.392930
#     4       4.831938     4.837502     5.032782     5.128692     5.106904
# ...              ...          ...          ...          ...          ...
# Jan 274    25.819029    25.834907    24.881533    24.829242    24.840900
#     275  1279.586746  1279.493141  1279.199721  1279.162492  1279.065676
#     276     0.915057     0.833606     0.827513     0.835027     0.835260
#     277     0.000000     0.000000     0.000000     0.000000     0.000000
#     278  2641.631414  2574.079821  2546.570278  2539.282126  2523.485197
#
#             02:00:00  ...  DST2  DST3  DST4  1900-01-01 00:00:00  dst1  dst2  \
# Dec 0      14.481883  ...   NaN   NaN   NaN                  NaN   NaN   NaN
#     1    2313.369622  ...   NaN   NaN   NaN                  NaN   NaN   NaN
#     2     330.223434  ...   NaN   NaN   NaN                  NaN   NaN   NaN
#     3    1322.662408  ...   NaN   NaN   NaN                  NaN   NaN   NaN
#     4       4.801135  ...   NaN   NaN   NaN                  NaN   NaN   NaN
# ...              ...  ...   ...   ...   ...                  ...   ...   ...
# Jan 274    24.848151  ...   NaN   NaN   NaN                  NaN   NaN   NaN
#     275  1279.160598  ...   NaN   NaN   NaN                  NaN   NaN   NaN
#     276     0.831634  ...   NaN   NaN   NaN                  NaN   NaN   NaN
#     277     0.000000  ...   NaN   NaN   NaN                  NaN   NaN   NaN
#     278  2485.511096  ...   NaN   NaN   NaN                  NaN   NaN   NaN
#
#          dst3  dst4      Date     Fuel
# Dec 0     NaN   NaN  12/01/16  Biomass
#     1     NaN   NaN  12/01/16     Coal
#     2     NaN   NaN  12/01/16      Gas
#     3     NaN   NaN  12/01/16   Gas-CC
#     4     NaN   NaN  12/01/16    Hydro
# ...       ...   ...       ...      ...
# Jan 274   NaN   NaN  01/31/16    Hydro
#     275   NaN   NaN  01/31/16  Nuclear
#     276   NaN   NaN  01/31/16    Other
#     277   NaN   NaN  01/31/16    Solar
#     278   NaN   NaN  01/31/16     Wind
#
# [3294 rows x 109 columns]

# %%
full_df = cdf[['Date', 'Fuel', 'Total']]

# %%
full_df
# Out:
#              Date     Fuel          Total
# Dec 0    12/01/16  Biomass    1368.853334
#     1    12/01/16     Coal  291089.503855
#     2    12/01/16      Gas   34755.195274
#     3    12/01/16   Gas-CC  229820.111721
#     4    12/01/16    Hydro    1344.980060
# ...           ...      ...            ...
# Jan 274  01/31/16    Hydro    2590.696536
#     275  01/31/16  Nuclear  122796.897712
#     276  01/31/16    Other      83.697152
#     277  01/31/16    Solar    1859.815680
#     278  01/31/16     Wind  143642.521471
#
# [3294 rows x 3 columns]

# %%
# https://stackoverflow.com/questions/66792082/pandas-python-how-to-transpose-duplicate-rows-to-columns-and-preserve-order
order = full_df['Date'].unique()
full_df = full_df.set_index([full_df.groupby('Fuel').cumcount(), 'Fuel'])['Total'].unstack()

# %%
# https://datascience.stackexchange.com/questions/48335/how-to-add-date-column-in-python-pandas-dataframe
full_df['date'] = pd.date_range(start='2016-01-01', periods=len(full_df), freq='D')

# %%
full_df
# Out:
# Fuel      Biomass           Coal           Gas         Gas-CC        Hydro  \
# 0     1368.853334  291089.503855  34755.195274  229820.111721  1344.980060
# 1     1255.218710  313123.473151  30362.668792  221503.187920  1404.934024
# 2     1133.164147  324559.508780  31033.070664  247550.892805  2127.863553
# 3     1078.572852  323975.854111  31278.088301  259744.297731  1475.954786
# 4     1232.391444  316348.761804  31302.012330  269375.868047  1428.192006
# ..            ...            ...           ...            ...          ...
# 361   1473.726076  224970.438099  51419.330823  492716.365591  3067.622819
# 362   1459.274187  223809.468311  52385.555917  465488.510715  3021.458447
# 363   1536.963218  177605.787646  29517.227697  298126.470399  2924.401468
# 364   1527.053245  172232.346519  28563.922114  219982.666280  2546.781382
