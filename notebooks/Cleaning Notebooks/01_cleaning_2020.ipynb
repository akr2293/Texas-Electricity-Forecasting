# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Let's start by reading in one year's worth a data to get a better feel

# %%
#df = pd.read_excel('/Users/andrewroberts/desktop/ga/capstone/Data/FuelMixReport_PreviousYears/IntGenByFuel2015.xls', sheet_name = ['Dec', 'Nov', 'Oct', 'Sep', 'Aug', 'Jul', 'Jun', 'May', 'Apr', 'Mar', 'Feb', 'Jan'], index_col = 'Date-Fuel')

# %%
df = pd.read_excel('/Users/andrewroberts/desktop/ga/capstone/Data/FuelMixReport_PreviousYears/IntGenByFuel2020.xlsx', sheet_name = None)

# %%
df.keys()
# Out:
# dict_keys(['data_Summary_1', 'data_Summary_2', 'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])

# %%
def data_loader(file):
    full_df = []
    for key in list(df.keys()):
        if "Summary" in key:
            del df[key]
#     key = key[['Date', 'Fuel', 'Total']]
    
#     order = key['Date'].unique()
    
#     key = key.set_index([key.groupby('Fuel').cumcount(), 'Fuel'])['Total'].unstack()
    
#     df_dec['date'] = pd.date_range(start='2019-12-01', periods=len(df_dec), freq='D') 
#     df_dec = df_dec.set_index('date')
    
    
#     full_df.append(each)

# %%
# def data_loader(file):
#     full_df = []
#     for each in file:
#         if "data_Summary_1" in df:
#             del df["data_Summary_1"]
#             print('deleted')
#         if "data_Summary_2" in df:
#             del df["data_Summary_2"]
        
#         print(each)

# %%
data_loader(df)

# %%
cdf = pd.concat(df,sort=False)

# %%
cdf
# Out:
#               Date     Fuel Settlement Type          Total         0:15  \
# Jan 0   2020-01-01  Biomass           FINAL     829.861577     8.897137
#     1   2020-01-01     Coal           FINAL  153415.741238  1424.554673
#     2   2020-01-01      Gas           FINAL   14934.575434   158.861450
#     3   2020-01-01   Gas-CC           FINAL  289658.378658  3173.084153
#     4   2020-01-01    Hydro           FINAL    1278.777580     6.412875
# ...            ...      ...             ...            ...          ...
# Dec 274 2020-12-31    Hydro           FINAL     528.396953     7.366314
#     275 2020-12-31  Nuclear           FINAL  122562.916565  1277.070082
#     276 2020-12-31    Other           FINAL       1.942955     0.028410
#     277 2020-12-31    Solar           FINAL    3252.561653     0.000000
#     278 2020-12-31     Wind           FINAL  350800.116658  3992.845820
#
#                 0:30         0:45         1:00         1:15         1:30  ...  \
# Jan 0       8.857404     8.780167     8.756302     8.982659     8.858266  ...
#     1    1424.204785  1452.406880  1463.547569  1447.432180  1436.953196  ...
#     2     160.416656   160.022975   158.432587   158.819729   158.254566  ...
#     3    3123.866670  3031.577518  2978.271208  2892.281623  2932.832050  ...
#     4       9.245649     6.952231     4.997161     9.405929     4.005906  ...
# ...              ...          ...          ...          ...          ...  ...
# Dec 274     7.643504     7.606045     7.552994     2.055400     1.450089  ...
#     275  1277.228678  1276.980585  1276.592824  1276.295866  1276.774551  ...
#     276     0.314063     1.099370    -0.834132    -0.145468     2.164066  ...
#     277     0.000000     0.000000     0.000055     0.000158     0.000126  ...
#     278  4013.836278  3997.932542  3992.832303  4088.059868  4144.893332  ...
#
#                22:45        23:00        23:15        23:30        23:45  \
# Jan 0       8.468771     8.473933     8.480197     8.474832     8.469678
#     1    1795.384043  1717.720251  1674.921768  1651.500306  1630.837442
#     2     153.671443   153.309924   153.757539   153.360790   152.697942
#     3    2511.862217  2469.942144  2436.472749  2422.100229  2372.924016
#     4      13.396014    12.553616     3.713749     3.197921     3.194895
# ...              ...          ...          ...          ...          ...
# Dec 274     2.280183     2.282065     2.085137     2.068902     2.070236
#     275  1275.136053  1275.209173  1274.704380  1275.156009  1275.375114
#     276     0.040701    -0.700178    -1.722901    -1.178360     0.513461
#     277     0.000526     0.000191     0.000224     0.000199     0.000276
#     278  3593.241771  3574.551367  3524.772837  3531.783512  3543.489949
#
#                 0:00  01:15 (DST)  01:30 (DST)  01:45 (DST)  02:00 (DST)
# Jan 0       8.478195          NaN          NaN          NaN          NaN
#     1    1636.090874          NaN          NaN          NaN          NaN
#     2     153.754631          NaN          NaN          NaN          NaN
#     3    2320.538850          NaN          NaN          NaN          NaN
#     4       3.205742          NaN          NaN          NaN          NaN
# ...              ...          ...          ...          ...          ...
# Dec 274     2.138327          NaN          NaN          NaN          NaN
#     275  1275.356463          NaN          NaN          NaN          NaN
#     276    -0.125755          NaN          NaN          NaN          NaN
#     277     0.000124          NaN          NaN          NaN          NaN
#     278  3503.785452          NaN          NaN          NaN          NaN
#
# [3294 rows x 104 columns]

# %%
full_df = cdf[['Date', 'Fuel', 'Total']]

# %%
full_df
# Out:
#               Date     Fuel          Total
# Jan 0   2020-01-01  Biomass     829.861577
#     1   2020-01-01     Coal  153415.741238
#     2   2020-01-01      Gas   14934.575434
#     3   2020-01-01   Gas-CC  289658.378658
#     4   2020-01-01    Hydro    1278.777580
# ...            ...      ...            ...
# Dec 274 2020-12-31    Hydro     528.396953
#     275 2020-12-31  Nuclear  122562.916565
#     276 2020-12-31    Other       1.942955
#     277 2020-12-31    Solar    3252.561653
#     278 2020-12-31     Wind  350800.116658
#
# [3294 rows x 3 columns]

# %%
# https://stackoverflow.com/questions/66792082/pandas-python-how-to-transpose-duplicate-rows-to-columns-and-preserve-order
order = full_df['Date'].unique()
full_df = full_df.set_index([full_df.groupby('Fuel').cumcount(), 'Fuel'])['Total'].unstack()

# %%
# https://datascience.stackexchange.com/questions/48335/how-to-add-date-column-in-python-pandas-dataframe
full_df['date'] = pd.date_range(start='2020-01-01', periods=len(full_df), freq='D')

# %%
full_df
# Out:
# Fuel     Biomass           Coal           Gas         Gas-CC        Hydro  \
# 0     829.861577  153415.741238  14934.575434  289658.378658  1278.777580
# 1     815.791618  196713.965407  17640.046331  313319.304998  2216.224027
# 2     825.492881  178036.893024  18017.523098  339497.056045  2240.834570
# 3     760.234727  194337.978392  19472.143562  375653.680264  2307.535835
# 4     729.143935  165773.447074  15548.693514  291698.473466  2193.512222
# ..           ...            ...           ...            ...          ...
# 361   635.255371  184407.678785  12629.842174  182007.744926   500.494667
# 362   591.302614  193621.421107  12041.562536  204434.235571   636.269588
# 363   667.202987  144900.104532  20169.062127  147785.442137   643.995831
# 364   704.598125  158272.638521  17970.573106  210013.087865   655.564849
# 365   691.216422  166031.079721  51900.515028  387944.848524   528.396953
#
# Fuel        Nuclear      Other         Solar           Wind       date
# 0     108440.074173 -28.933694   3954.234317  349713.472491 2020-01-01
# 1      92305.814149 -29.794426   7181.875467  272849.904152 2020-01-02
# 2      95549.535643 -37.884666  10759.906768  266141.718609 2020-01-03
# 3     116273.206678 -59.473340  15787.615071  191189.675041 2020-01-04
# 4     122064.434206  69.489137  15409.573022  266110.656668 2020-01-05
# ..              ...        ...           ...            ...        ...
# 361   122762.954790  13.731479  29820.239198  321323.147861 2020-12-27
# 362   122720.408975 -13.652177  19924.960198  350947.810220 2020-12-28
# 363   122664.769337 -26.962775  11594.382815  443182.060206 2020-12-29
# 364   122629.625647  19.636788   3539.284392  434953.837358 2020-12-30
# 365   122562.916565   1.942955   3252.561653  350800.116658 2020-12-31
#
# [366 rows x 10 columns]

# %%
full_df = full_df.set_index('date')

# %%
full_df
# Out:
# Fuel           Biomass           Coal           Gas         Gas-CC  \
# date
# 2020-01-01  829.861577  153415.741238  14934.575434  289658.378658
# 2020-01-02  815.791618  196713.965407  17640.046331  313319.304998
# 2020-01-03  825.492881  178036.893024  18017.523098  339497.056045
# 2020-01-04  760.234727  194337.978392  19472.143562  375653.680264
# 2020-01-05  729.143935  165773.447074  15548.693514  291698.473466
# ...                ...            ...           ...            ...
# 2020-12-27  635.255371  184407.678785  12629.842174  182007.744926
# 2020-12-28  591.302614  193621.421107  12041.562536  204434.235571
# 2020-12-29  667.202987  144900.104532  20169.062127  147785.442137
# 2020-12-30  704.598125  158272.638521  17970.573106  210013.087865
# 2020-12-31  691.216422  166031.079721  51900.515028  387944.848524
#
# Fuel              Hydro        Nuclear      Other         Solar           Wind
# date
# 2020-01-01  1278.777580  108440.074173 -28.933694   3954.234317  349713.472491
# 2020-01-02  2216.224027   92305.814149 -29.794426   7181.875467  272849.904152
# 2020-01-03  2240.834570   95549.535643 -37.884666  10759.906768  266141.718609
# 2020-01-04  2307.535835  116273.206678 -59.473340  15787.615071  191189.675041
# 2020-01-05  2193.512222  122064.434206  69.489137  15409.573022  266110.656668
# ...                 ...            ...        ...           ...            ...
# 2020-12-27   500.494667  122762.954790  13.731479  29820.239198  321323.147861
# 2020-12-28   636.269588  122720.408975 -13.652177  19924.960198  350947.810220
# 2020-12-29   643.995831  122664.769337 -26.962775  11594.382815  443182.060206
# 2020-12-30   655.564849  122629.625647  19.636788   3539.284392  434953.837358
# 2020-12-31   528.396953  122562.916565   1.942955   3252.561653  350800.116658
#
# [366 rows x 9 columns]

# %% [markdown]
# ### Let's combine 'Gas' & 'Gas-CC' as one column - 'NGas' for natural gas

# %%
full_df['NGas'] = full_df['Gas'] + full_df['Gas-CC']
full_df.drop(columns = ['Gas', 'Gas-CC'], inplace = True)

# %%
full_df.plot(figsize=(15,9)).legend(title='Source', bbox_to_anchor=(1, 1));

# %%
sns.pairplot(full_df, corner=True)

# %%
plt.figure(figsize=(9,9))
sns.boxplot(data = full_df,
            
            );

# %% [markdown]
# ### Export the cleaned data

# %%
full_df.to_csv('../data/final_dfs/2020_clean.csv')
